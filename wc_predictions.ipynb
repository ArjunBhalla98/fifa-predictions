# %%
import pandas as pd
import numpy as np
import math

seed = 1234

# %%
wc_data = pd.read_csv("wc_dataset/WorldCupMatches.csv").dropna()
wc_data.sample(3, random_state=seed)
# Out:
#        Year               Datetime           Stage                 Stadium  \
# 104  1958.0   08 Jun 1958 - 19:00          Group 3              Jarnvallen
# 767  2010.0   03 Jul 2010 - 20:30   Quarter-finals      Ellis Park Stadium
# 588  2002.0  03 June 2002 - 18:00          Group C  Munsu Football Stadium
#
#               City Home Team Name  Home Team Goals  Away Team Goals  \
# 104     Sandviken         Hungary              1.0              1.0
# 767  Johannesburg        Paraguay              0.0              1.0
# 588         Ulsan          Brazil              2.0              1.0
#
#     Away Team Name Win conditions  Attendance  Half-time Home Goals  \
# 104          Wales                    15343.0                   1.0
# 767          Spain                    55359.0                   0.0
# 588         Turkey                    33842.0                   0.0
#
#      Half-time Away Goals                   Referee           Assistant 1  \
# 104                   1.0  CODESAL Jose Maria (URU)     LEMESIC Leo (YUG)
# 767                   0.0       BATRES Carlos (GUA)     LEAL Leonel (CRC)
# 588                   1.0       KIM Young Joo (KOR)  KRISHNAN Visva (SIN)
#
#                   Assistant 2     RoundID      MatchID Home Team Initials  \
# 104   VAN NUFFEL Lucien (BEL)       220.0       1407.0                HUN
# 767     PASTRANA Carlos (HON)    249718.0  300061506.0                PAR
# 588  FERNANDEZ Vladimir (SLV)  43950100.0   43950010.0                BRA
#
#     Away Team Initials
# 104                WAL
# 767                ESP
# 588                TUR

# %%
team_matchups = {}

for row in wc_data.itertuples():
    t1 = row._19
    t2 = row._20
    order = list(sorted([t1,t2]))
    tup = (order[0], order[1])
    
    if tup in team_matchups:
        team_matchups[tup] += 1
    else:
        team_matchups[tup] = 1

print(team_matchups)
print(len(list(filter(lambda x: x > 1, team_matchups.values()))), len(team_matchups.values()))
# Out:
# {('FRA', 'MEX'): 4, ('BEL', 'USA'): 3, ('BRA', 'YUG'): 4, ('PER', 'ROU'): 1, ('ARG', 'FRA'): 2, ('CHI', 'MEX'): 1, ('BOL', 'YUG'): 1, ('PAR', 'USA'): 1, ('PER', 'URU'): 1, ('CHI', 'FRA'): 1, ('ARG', 'MEX'): 3, ('BOL', 'BRA'): 1, ('BEL', 'PAR'): 2, ('ROU', 'URU'): 1, ('ARG', 'CHI'): 1, ('ARG', 'USA'): 1, ('URU', 'YUG'): 2, ('ARG', 'URU'): 2, ('AUT', 'FRA'): 2, ('EGY', 'HUN'): 1, ('NED', 'SUI'): 1, ('ARG', 'SWE'): 2, ('BEL', 'GER'): 2, ('BRA', 'ESP'): 5, ('ITA', 'USA'): 3, ('ROU', 'TCH'): 2, ('SUI', 'TCH'): 1, ('GER', 'SWE'): 2, ('ESP', 'ITA'): 3, ('AUT', 'HUN'): 1, ('AUT', 'ITA'): 4, ('GER', 'TCH'): 1, ('AUT', 'GER'): 1, ('ITA', 'TCH'): 2, ('GER', 'SUI'): 2, ('HUN', 'INH'): 1, ('BEL', 'FRA'): 2, ('CUB', 'ROU'): 2, ('ITA', 'NOR'): 3, ('BRA', 'POL'): 4, ('NED', 'TCH'): 1, ('BRA', 'TCH'): 5, ('HUN', 'SUI'): 1, ('CUB', 'SWE'): 1, ('FRA', 'ITA'): 5, ('HUN', 'SWE'): 2, ('BRA', 'ITA'): 5, ('BRA', 'SWE'): 7, ('HUN', 'ITA'): 2, ('BRA', 'MEX'): 4, ('CHI', 'ENG'): 1, ('ESP', 'USA'): 1, ('ITA', 'SWE'): 2, ('SUI', 'YUG'): 1, ('BRA', 'SUI'): 1, ('MEX', 'YUG'): 1, ('CHI', 'ESP'): 3, ('PAR', 'SWE'): 2, ('ENG', 'USA'): 2, ('ENG', 'ESP'): 2, ('ITA', 'PAR'): 2, ('BOL', 'URU'): 1, ('MEX', 'SUI'): 1, ('CHI', 'USA'): 1, ('ESP', 'URU'): 2, ('SWE', 'URU'): 3, ('ESP', 'SWE'): 2, ('BRA', 'URU'): 2, ('TCH', 'URU'): 1, ('AUT', 'SCO'): 1, ('FRA', 'YUG'): 2, ('FRG', 'TUR'): 2, ('HUN', 'KOR'): 1, ('BEL', 'ENG'): 2, ('ITA', 'SUI'): 3, ('SCO', 'URU'): 2, ('AUT', 'TCH'): 2, ('FRG', 'HUN'): 2, ('KOR', 'TUR'): 2, ('ENG', 'SUI'): 1, ('BEL', 'ITA'): 1, ('ENG', 'URU'): 3, ('AUT', 'SUI'): 1, ('FRG', 'YUG'): 5, ('BRA', 'HUN'): 2, ('AUT', 'FRG'): 3, ('HUN', 'URU'): 1, ('AUT', 'URU'): 1, ('MEX', 'SWE'): 1, ('ENG', 'URS'): 2, ('ARG', 'FRG'): 4, ('HUN', 'WAL'): 2, ('FRA', 'PAR'): 2, ('SCO', 'YUG'): 2, ('AUT', 'BRA'): 2, ('NIR', 'TCH'): 2, ('BRA', 'ENG'): 4, ('MEX', 'WAL'): 1, ('PAR', 'SCO'): 1, ('AUT', 'URS'): 1, ('FRG', 'TCH'): 2, ('ARG', 'NIR'): 1, ('SWE', 'WAL'): 1, ('BRA', 'URS'): 2, ('FRG', 'NIR'): 1, ('HUN', 'MEX'): 1, ('PAR', 'YUG'): 1, ('FRA', 'SCO'): 1, ('AUT', 'ENG'): 1, ('ARG', 'TCH'): 1, ('BRA', 'WAL'): 1, ('SWE', 'URS'): 1, ('FRA', 'NIR'): 2, ('FRG', 'SWE'): 2, ('BRA', 'FRA'): 4, ('FRA', 'FRG'): 3, ('COL', 'URU'): 3, ('ARG', 'BUL'): 3, ('CHI', 'SUI'): 2, ('URS', 'YUG'): 1, ('ESP', 'TCH'): 1, ('ENG', 'HUN'): 1, ('FRG', 'ITA'): 4, ('ARG', 'ENG'): 5, ('CHI', 'ITA'): 3, ('COL', 'URS'): 1, ('ESP', 'MEX'): 1, ('BUL', 'HUN'): 2, ('FRG', 'SUI'): 2, ('URS', 'URU'): 2, ('ARG', 'HUN'): 3, ('CHI', 'FRG'): 3, ('COL', 'YUG'): 2, ('MEX', 'TCH'): 1, ('BUL', 'ENG'): 1, ('CHI', 'URS'): 2, ('HUN', 'TCH'): 1, ('TCH', 'YUG'): 1, ('BRA', 'CHI'): 5, ('CHI', 'YUG'): 1, ('BRA', 'BUL'): 1, ('PRK', 'URS'): 1, ('HUN', 'POR'): 1, ('ARG', 'ESP'): 1, ('FRA', 'URU'): 3, ('ESP', 'SUI'): 3, ('CHI', 'PRK'): 1, ('BUL', 'POR'): 1, ('ITA', 'URS'): 1, ('ENG', 'MEX'): 1, ('MEX', 'URU'): 2, ('ARG', 'SUI'): 3, ('BRA', 'POR'): 2, ('ITA', 'PRK'): 1, ('ENG', 'FRA'): 2, ('ESP', 'FRG'): 2, ('FRG', 'URU'): 3, ('HUN', 'URS'): 2, ('POR', 'PRK'): 2, ('FRG', 'URS'): 1, ('ENG', 'POR'): 3, ('POR', 'URS'): 1, ('ENG', 'FRG'): 4, ('MEX', 'URS'): 1, ('ISR', 'URU'): 1, ('BUL', 'PER'): 1, ('ENG', 'ROU'): 2, ('FRG', 'MAR'): 2, ('BEL', 'SLV'): 2, ('ITA', 'URU'): 3, ('MAR', 'PER'): 1, ('BEL', 'URS'): 3, ('ISR', 'SWE'): 1, ('BUL', 'FRG'): 1, ('MEX', 'SLV'): 1, ('FRG', 'PER'): 1, ('BRA', 'ROU'): 1, ('SLV', 'URS'): 1, ('ISR', 'ITA'): 1, ('BUL', 'MAR'): 1, ('ENG', 'TCH'): 2, ('BEL', 'MEX'): 3, ('ITA', 'MEX'): 3, ('BRA', 'PER'): 2, ('AUS', 'GDR'): 1, ('SCO', 'ZAI'): 1, ('NED', 'URU'): 2, ('BUL', 'SWE'): 2, ('HAI', 'ITA'): 1, ('ARG', 'POL'): 2, ('AUS', 'FRG'): 1, ('BRA', 'SCO'): 4, ('CHI', 'GDR'): 1, ('YUG', 'ZAI'): 1, ('NED', 'SWE'): 1, ('BUL', 'URU'): 1, ('HAI', 'POL'): 1, ('ARG', 'ITA'): 5, ('AUS', 'CHI'): 2, ('BRA', 'ZAI'): 1, ('FRG', 'GDR'): 1, ('BUL', 'NED'): 1, ('ARG', 'HAI'): 1, ('ITA', 'POL'): 3, ('BRA', 'GDR'): 1, ('ARG', 'NED'): 6, ('POL', 'SWE'): 1, ('ARG', 'BRA'): 4, ('POL', 'YUG'): 1, ('GDR', 'NED'): 1, ('FRG', ' ...
# 172 577

# %%
def calculate_lambda(t1, t2):
    """
    Lambda = w1 * (avg goals for t1) + w2 * (avg goals for t1 against t2)
    w1 + w2 = 1
    
    returns lambda_t1
    """
    w1 = 0.8
    w2 = 0.2
    t1_df_home = wc_data[(wc_data["Home Team Initials"] == t1)]
    t1_df_away = wc_data[(wc_data["Away Team Initials"] == t1)]
    avg_goals_t1 = (lazy_mean(list(t1_df_home[t1_df_home["Away Team Initials"] != t2]["Home Team Goals"])) + lazy_mean(list(t1_df_away[t1_df_away["Home Team Initials"] != t2]["Away Team Goals"]))) / 2
    avg_goals_vs_t2 = (lazy_mean(list(t1_df_home[t1_df_home["Away Team Initials"] == t2]["Home Team Goals"])) + lazy_mean(list(t1_df_away[t1_df_away["Home Team Initials"] == t2]["Away Team Goals"]))) / 2
    
    return (w1 * avg_goals_t1) + (w2 * avg_goals_vs_t2)

def lazy_mean(arr):
    if len(arr) == 0:
        return 0
    
    return sum(arr) / len(arr)

def predict_proba(k, lbd):
    return ((lbd ** k) * (math.e ** (-lbd))) / math.factorial(k)

# %%
team_pairs = [("BRA", "SUI"), ("POR", "URU")]

for t1, t2 in team_pairs:
    max_p = -1
    max_g1 = -1
    max_g2 = -1
    
    for g1 in range(0, 11):
        for g2 in range(0, 11):
            lbd_t1 = calculate_lambda(t1, t2)
            lbd_t2 = calculate_lambda(t2, t1)
            p_t1 = predict_proba(g1, lbd_t1)
            p_t2 = predict_proba(g2, lbd_t2)
            p_combo = p_t1 * p_t2
            
            if p_combo > max_p:
                max_p = p_combo
                max_g1 = g1
                max_g2 = g2
    print(f"Team {t1} v {t2}: {max_g1} - {max_g2}, prob: {max_p}")
# Out:
# Team BRA v SUI: 1 - 1, prob: 0.10590145934453563
# Team POR v URU: 1 - 1, prob: 0.13135463428853397

# %%
for t1, t2 in team_pairs:
    lbd_t1 = calculate_lambda(t1, t2)
    lbd_t2 = calculate_lambda(t2, t1)
    t1_goals = round(lbd_t1)
    t2_goals = round(lbd_t2)
    
    print(f"Team {t1} v {t2}: {t1_goals} - {t2_goals}, {lbd_t1} - {lbd_t2}")
# Out:
# Team BRA v SUI: 2 - 1, 1.7713200379867047 - 1.3333333333333333
# Team POR v URU: 1 - 1, 1.1800000000000002 - 1.1857142857142857
